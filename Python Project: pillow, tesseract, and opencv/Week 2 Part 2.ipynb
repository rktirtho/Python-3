# %%
from PIL import Image
import pytesseract

# %%
image = Image.open('images/index.png')
text = pytesseract.image_to_string(image)

# %%
print(text)
# Out:
#
#
# erm Master of Science in Information
#
# INFORMATION

# %%
image = image.convert("L")
image
# Out:
# <PIL.Image.Image image mode=L size=800x450 at 0x7FCDB9B8DE50>

# %%
all = pytesseract.image_to_string(image)

# %%
print(all)
# Out:
# ema Master of Science in Information
#
# INFORMATION
#
#
#
# i eo jf oi - o 2
# rs ian), § So hs a :
