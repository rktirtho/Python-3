# %%
import PIL
from PIL import Image

# %%
image = Image.open('images/index.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=800x450 at 0x7FF6485ED190>

# %%
image.show()

# %%
import inspect

inspect.getmro(type(image))
# Out:
# (PIL.PngImagePlugin.PngImageFile,
#  PIL.ImageFile.ImageFile,
#  PIL.Image.Image,
#  object)

# %%
from IPython.display import display

display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=800x450 at 0x7FF6485ED190>

# %%
display(image.crop((200,70,750,110)))
# Out:
# <PIL.Image.Image image mode=P size=550x40 at 0x7FF62A33FD30>

# %%
croped  =  image.crop((200,70,750,110))

# %%
croped
# Out:
# <PIL.Image.Image image mode=P size=550x40 at 0x7FF6299D5CD0>

# %%
from PIL import ImageFilter
image =  image.convert('RGB')
blured_image =  image.filter(PIL.ImageFilter.BLUR)

# %%
blured_image.show()

# %%
from PIL import ImageDraw
drawing_object= ImageDraw.Draw(image)

# %%
drawing_object

# %%
help(drawing_object.text)
# Out:
# Help on method text in module PIL.ImageDraw:
#
# text(xy, text, fill=None, font=None, anchor=None, spacing=4, align='left', direction=None, features=None, language=None, stroke_width=0, stroke_fill=None, *args, **kwargs) method of PIL.ImageDraw.ImageDraw instance

# %%
drawing_object.rectangle((200,70,750,110), fill= 'red', outline="red")

# %%
display(drawing_object)

# %%
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7FF62889A9A0>
